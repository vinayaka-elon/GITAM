# %% [markdown]
# ### Mid-term (**BUAN 7051: Decision Sciences with Python**)

# %% [markdown]
# ![Screenshot 2025-01-05 072659.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-01-05 072918.png](data:image/png;base64,...)
